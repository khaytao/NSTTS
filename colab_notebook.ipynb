# %%
try:
    from google.colab import drive
    from google.colab import files
    drive.mount('/content/drive')
except ImportError:
    print("Google Drive is not mounted")

kfir_dir_name = r"/content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS"
# yossi_dir_name =

dir_name = kfir_dir_name
# Change to your specific directory'
# %cd {dir_name}

# Verify current directory
# !pwd
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS
# /content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS
# colab_notebook.ipynb	main.py		  __pycache__
# colab_requirements.txt	ProDiff		  README.md
# ControlNet		prodiff_reqs	  run_tts.py
# get_model.py		prodiff_reqs.txt  TODO.txt
# main_notebook.ipynb	Project_files	  venv_dgm_final_project.yml

# %%
import os

# %%
# !pip install -r colab_requirements.txt

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
# %cd {dir_name}
# !python run_tts.py
# Out:
# /content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS
# /content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS/ProDiff True
# /content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS
# N=8,text='Hello this is a test.'
# 2025-05-15 14:23:47.239404: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747319027.463404    2154 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747319027.522711    2154 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd {dir_name}
# !ls
# !python main.py
# Out:
# /content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS
# colab_notebook.ipynb	main.py		  __pycache__
# colab_requirements.txt	ProDiff		  README.md
# ControlNet		prodiff_reqs	  run_tts.py
# get_model.py		prodiff_reqs.txt  TODO.txt
# main_notebook.ipynb	Project_files	  venv_dgm_final_project.yml
# /content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS/ProDiff True
# /content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS
# /content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS/ProDiff True
# /content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS
# 2025-05-15 14:25:29.459755: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
output_directory_path = os.path.join(dir_name, "ProDiff/infer_out/")
# %cd {output_directory_path}
# !ls
# !zip -r /content/prodiff_download.zip "."
files.download('/content/prodiff_download.zip')
# Out:
# /content/drive/MyDrive/2024 main folder/School/2025/Semester A/DeepGen/project/code/NSTTS/ProDiff/infer_out
# 'Hello this is a test..wav'
# updating: Hello this is a test..wav (deflated 16%)
